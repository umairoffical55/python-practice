# %%
print(5+3)
print(8-3)
# Out:
# 8
# 5

# %%
print(2*6)
print(5 / 3)
print(25 // 3)
# Out:
# 12
# 1.6666666666666667
# 8

# %%
print(10 % 6)
print(2**7)
# Out:
# 4
# 128

# %%
print(5 == 4)
print(3 != 3)
print(3>2)
print(3<0)
# Out:
# False
# False
# True
# False

# %%
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False

# %%
x=10
print(x)
x += 5
print(x)
x -= 4
print(x
