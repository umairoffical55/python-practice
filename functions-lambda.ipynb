# %%
add = lambda a,b: a+b
print(add(1,8))
# Out:
# 9

# %%
double_it = lambda n:n*2

# %%
print(double_it(5))
# Out:
# 10

# %%
nums = [1,2,3,4,5]
squares = list(map(lambda x:x*x, nums))

# %%
print(squares)
# Out:
# [1, 4, 9, 16, 25]
