# %%
temp =(int (input("enter temperature"))
# Out:
#   Cell In[12], line 1
#     temp =(int (input("enter temperature"))
#                                            ^
# _IncompleteInputError: incomplete input

# %%
if temp > 35:
    print("it is hot wether")
else:
    print("it is not hot wether")
# Out:
# it is hot wether
