# %%
age = "34"

# %%
print(age)
# Out:
# 34

# %%
type(age)
# Out:
# str

# %%
print(int(age)+1)
# Out:
# 35

# %%
input("please write your age")
# Out:
# please write your age 22
# '22'

# %%
age = input("please write your age")
# Out:
# please write your age 22

# %%
type(age)
# Out:
# str

# %%
myAge = int(age)

# %%
type(age)
# Out:
# str
