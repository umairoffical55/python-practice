# %%
student = {"name": "Ali", "age": 20, "grade": "A"}

for key in student:
    print(key)
# Out:
# name
# age
# grade

# %%
student = {"name": "Ali", "age": 20, "grade": "A"}

for key in student:
    print(student[key])
# Out:
# Ali
# 20
# A

# %%
student = {"name": "Ali", "age": 20, "grade": "A"}

for key in student:
    print(key , ":", student[key])
# Out:
# name : Ali
# age : 20
# grade : A
