# %%
age=25

# %%
print(age)
# Out:
# 25

# %%
score=3.5

# %%
print(score)
# Out:
# 3.5

# %%
type(score)
# Out:
# float

# %%
print(score+1)
# Out:
# 4.5

# %%
name="ali zafar"

# %%
print(name)
# Out:
# ali zafar

# %%
print(name + "ahmad", "zafar", "umair")
# Out:
# ali zafarahmad zafar umair

# %%
is_passed = True

# %%
print(is_passed)
# Out:
# True
